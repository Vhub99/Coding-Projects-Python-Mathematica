# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import constants as sc

# %%
k = sc.k
T1 = 300
T2 = 600
u = sc.physical_constants['atomic mass constant'][0]
m = 28*u
vm1 = ((2*k*T1)/m)**(1/2)
vm2 =((2*k*T2)/m)**(1/2)
D1 = lambda v: (4*(v**2)/(((np.pi)**(1/2))*vm1**3))*np.exp(-(v**2)/vm1**2)
D2 = lambda v: (4*(v**2)/(((np.pi)**(1/2))*vm2**3))*np.exp(-(v**2)/vm2**2)

print("speed at T=300K:", vm1, "speed at T=600K:", vm2)

v = np.arange(0,2500) 
D1val = D1(v1), D1(v2),D1(v3),D1(v4),D1(v5),D1(v6),D1(v7),D1(v8),D1(v9)
D2val = D2(v1), D2(v2),D2(v3),D2(v4),D2(v5),D2(v6),D2(v7),D2(v8),D2(v9)

fig = plt.figure()
ax = fig.add_axes([0.15,0.1,0.8,0.8])
ax.plot(v,D1(v), label='$T=300K$')
ax.plot(v,D2(v), label='$T=600K$')
ax.legend();
# Out:
# speed at T=300K: 422.0983963068972 speed at T=600K: 596.9372767131475
